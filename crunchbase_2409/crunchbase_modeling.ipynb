# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data_dir = "/workspaces/Gooopung/crunchbase_2409/space_prep.csv"
total_data = pd.read_csv(data_dir)
total_data.head()
# Out:
#    LinkedIn  Twitter  Facebook  \
# 0         1        1         0
# 1         0        0         0
# 2         1        0         0
# 3         0        0         0
# 4         1        1         0
#
#                                      Industry Groups  \
# 0  Commerce and Shopping, Information Technology,...
# 1             Manufacturing, Science and Engineering
# 2  Commerce and Shopping, Consumer Electronics, C...
# 3  Hardware, Science and Engineering, Software, T...
# 4  Artificial Intelligence (AI), Data and Analyti...
#
#    Number of Funding Rounds  Closed Date Last Equity Funding Type  IPO Status  \
# 0                       1.0            0                 Pre-Seed           0
# 1                       1.0            0                    Angel           0
# 2                       0.0            0                        0           0
# 3                       0.0            0                        0           0
# ...
